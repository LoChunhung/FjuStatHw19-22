# %% [markdown]
# ### Team No:5
# ### Team members: (1) 應統碩職二 408145137 駱俊宏 &emsp;(2)  應統碩一   410336130 陳冠廷

# %%
import pandas as pd

# %% [markdown]
# ## 1. 調整輸入範例檔案，空值改為 ss
# ### 說明: 原本範例檔案, 空值就是python預先認可的NaN類型的一種，所以 na_values不會有任何作用
# (原始) ![image.png](attachment:image.png) (修改) ![image-3.png](attachment:image-3.png)

# %%
dataframe = pd.read_csv("ch03-09-test.csv")
print(dataframe)
# Out:
#   'Name'  'c1' 'c2' 'c3'
# 0   '張三'    89  100   95
# 1   '李四'    70   68   80
# 2   '王二'    80   ss   75
# 3   '麻子'    84   90   ss

# %% [markdown]
# ## 2. 需要將ss視為以缺失值來處理
# ### 2.1 使用keep_deault_na = false
# ### 2.2 使用 na_values = "ss"

# %%
dataframe = pd.read_csv("ch03-09-test.csv",keep_default_na = False, na_values = "ss"  )
print(dataframe)
# Out:
#   'Name'  'c1'   'c2'  'c3'
# 0   '張三'    89  100.0  95.0
# 1   '李四'    70   68.0  80.0
# 2   '王二'    80    NaN  75.0
# 3   '麻子'    84   90.0   NaN

# %% [markdown]
# 參考連結: https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html
# ![image.png](attachment:image.png)
